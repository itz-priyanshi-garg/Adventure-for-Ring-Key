# %%
c=-1
def hall():
    global c
    c+=1
    h={"N":"You are in kitchen","E":"You are in Study room","W":"You are in Dining room","S":"You are in Store"}
    while 1:
        ct=time.time()
        if((lev==4)and(ct-st>=30)):
            print("Your time up\nYou Lose Level 4 Game")
            break
        if(c>8 and lev==3):
                print("Number Of Steps Exceeded\nYou Lose The Level 3 Game")
                break
        print("you have ",l)
        print("Enter -1 to quit")
        print("Enter Direction to move : ")
        q=input()
        if(q=="S"):
            print(h.get(q))
            store()
            break
        elif(q=="W"):
            print(h.get(q))
            dining()
            break
        elif(q=="E"):
            print(h.get(q))
            study()
            break
        elif(q=="N"):
            print(h.get(q))
            kitchen()
            break
        elif(q=="-1"):
            print("You Quit")
            break
        else:
            print("Invalid input")
    return
def kitchen():
    global c
    c+=1
    k={"N":"You can't move further in this direction" ,"E":"You are in Washroom","W":"You are in Living room","S":"You are in Hall"}
    while 1:
        ct=time.time()
        if((lev==4)and(ct-st>=30)):
            print("Your time up\nYou Lose Level 4 Game")
            break
        if(c>8 and lev==3):
                print("Number Of Steps Exceeded\nYou Lose The Level 3 Game")
                break
        print("you have ",l)
        print("Enter -1 to quit")
        print("Enter Direction to move : ")
        q=input()
        if(q=="S"):
            print(k.get(q))
            hall()
            break
        elif(q=="W"):
            print(k.get(q))
            living()
            break
        elif(q=="E"):
            print(k.get(q))
            wash()
            break
        elif(q=="N"):
            print(k.get(q))
            kitchen()
            break
        elif(q=="-1"):
            print("You Quit")
            break
        else:
            print("Invalid input")
    return
def store():
    global c
    c+=1
    s={"N":"You are in Hall","E":"You are in Garden","W":"You are in Lobby","S":"You can't move further in this direction"}
    while 1:
        ct=time.time()
        if((lev==4)and(ct-st>=30)):
            print("Your time up\nYou Lose Level 4 Game")
            break
        if(c>8 and lev==3):
                print("Number Of Steps Exceeded\nYou Lose The Level 3 Game")
                break
        print("you have ",l)
        print("Enter -1 to quit")
        print("Enter Direction to move : ")
        q=input()
        if(q=="S"):
            print(s.get(q))
            store()
            break
        elif(q=="W"):
            print(s.get(q))
            lobby()
            break
        elif(q=="E"):
            print(s.get(q))
            garden()
            break
        elif(q=="N"):
            print(s.get(q))
            hall()
            break
        elif(q=="-1"):
            print("You Quit")
            break
        else:
            print("Invalid input")
    return
def living():
    print("Where monster live.\nMonster catch you\nYou lose")
    return
def lobby():
    print("Where monster live.\nMonster catch you\nYou lose")
    return
def study():
    print("Where monster live.\nMonster catch you\nYou lose")
    return
def dining():
    global c
    c+=1
    if("Ring" not in l):
        l.append("Ring")
    global r
    r=1
    d={"E":"You are in Hall","N":"You are in Living room","S":"You are in Lobby","W":"You can't move further in this direction"}
    while 1:
        ct=time.time()
        if((lev==4)and(ct-st>=30)):
            print("Your time up\nYou Lose Level 4 Game")
            break
        if(c>8 and lev==3):
                print("Number Of Steps Exceeded\nYou Lose The Level 3 Game")
                break
        print("you have ",l)
        print("Enter -1 to quit")
        print("Enter Direction to move : ")
        q=input()
        if(q=="S"):
            print(d.get(q))
            lobby()
            break
        elif(q=="W"):
            print(d.get(q))
            dining()
            break
        elif(q=="E"):
            print(d.get(q))
            hall()
            break
        elif(q=="N"):
            print(d.get(q))
            living()
            break
        elif(q=="-1"):
            print("You Quit")
            break
        else:
            print("Invalid input")
    return
def wash():
    global c
    c+=1
    if("Key" not in l):
        l.append("Key")
    global k
    k=1
    w={"E":"You are in Washroom","N":"You can't move further in this direction","S":"You are in Study room","W":"You are in Kitchen"}
    while 1:
        ct=time.time()
        if((lev==4)and(ct-st>=30)):
            print("Your time up\nYou Lose Level 4 Game")
            break
        if(c>8 and lev==3):
                print("Number Of Steps Exceeded\nYou Lose The Level 3 Game")
                break
        print("you have ",l)
        print("Enter -1 to quit")
        print("Enter Direction to move : ")
        q=input()
        if(q=="S"):
            print(w.get(q))
            study()
            break
        elif(q=="W"):
            print(w.get(q))
            kitchen()
            break
        elif(q=="E"):
            print(w.get(q))
            wash()
            break
        elif(q=="N"):
            print(w.get(q))
            wash()
            break
        elif(q=="-1"):
            print("You Quit")
            break
        else:
            print("Invalid input")
    return
def garden():
    global c
    c+=1
    if((not((r==1) and (k==1)) and lev!=1) or ((r!=1 and k!=1)and lev==1)):
        g={"E":"You can't move further in this direction","N":"You are in Study room","S":"You are in Garden","W":"You are in Store"}
        while 1:
            ct=time.time()
            if((lev==4)and(ct-st>=30)):
                print("Your time up\nYou Lose Level 4 Game")
                break
            if(c>8 and lev==3):
                print("Number Of Steps Exceeded\nYou Lose The Level 3 Game")
                break
            print("you have ",l)
            print("Enter -1 to quit")
            print("Enter Direction to move : ")
            q=input()
            if(q=="S"):
                print(g.get(q))
                garden()
                break
            elif(q=="W"):
                print(g.get(q))
                store()
                break
            elif(q=="E"):
                p1rint(g.get(q))
                garden()
                break
            elif(q=="N"):
                print(g.get(q))
                study()
                break
            elif(q=="-1"):
                print("You Quit")
                break
            else:
                print("Invalid input")
    else:
        if(lev==1 and (r==1 or k==1)):
            print("You Won Level 1 Game\nCONGRATS!!!")
        elif(lev==2 and r==1 and k==1):
            print("You Won Level 2 Game\nCONGRATS!!!")
        elif(lev==3 and r==1 and k==1):
            print("You Won Level 3 Game In %d Steps\nCONGRATS!!!"%c)
        else:
             print("You Won Level 4 Game \nCONGRATS!!!")
    return    
import time        
l=[]
r=0
k=0
print("There Are Four Levels")
lev=int(input("Enter the Level no. You Want To Play :"))
if(lev==3):
    print("YOU HAVE TO COMPLETE THIS GAME IN 8 Steps")
if(lev==4):
    print("YOU HAVE TO COMPLETE THIS GAME IN 30 sec\nYOUR TIME STARTS NOW")
print("Enter N for up\nEnter S for down\nEnter W for left\nEnter E for right")
print("You are in the hall")
st=time.time()
hall()
# Out:
# There Are Four Levels
# Enter the Level no. You Want To Play :1
# Enter N for up
# Enter S for down
# Enter W for left
# Enter E for right
# You are in the hall
# you have  []
# Enter -1 to quit
# Enter Direction to move :
# S
# You are in Store
# you have  []
# Enter -1 to quit
# Enter Direction to move :
# S
# You can't move further in this direction
# you have  []
# Enter -1 to quit
# Enter Direction to move :
# W
# You are in Lobby
# Where monster live.
# Monster catch you
# You lose
